#    ------------------------------ -------- 186.6/241.3 MB 10.6 MB/s eta 0:00:06
#    ------------------------------ -------- 189.3/241.3 MB 10.6 MB/s eta 0:00:05
#    ------------------------------- ------- 192.2/241.3 MB 10.7 MB/s eta 0:00:05
#    ------------------------------- ------- 194.5/241.3 MB 10.7 MB/s eta 0:00:05
#    ------------------------------- ------- 196.6/241.3 MB 10.7 MB/s eta 0:00:05
#    -------------------------------- ------ 199.0/241.3 MB 10.7 MB/s eta 0:00:04
#    -------------------------------- ------ 201.6/241.3 MB 10.7 MB/s eta 0:00:04
#    --------------------------------- ----- 204.5/241.3 MB 10.7 MB/s eta 0:00:04
#    --------------------------------- ----- 206.8/241.3 MB 10.7 MB/s eta 0:00:04
#    --------------------------------- ----- 209.2/241.3 MB 10.7 MB/s eta 0:00:04
#    ---------------------------------- ---- 212.1/241.3 MB 10.7 MB/s eta 0:00:03
#    ---------------------------------- ---- 215.0/241.3 MB 10.8 MB/s eta 0:00:03
#    ----------------------------------- --- 217.3/241.3 MB 10.8 MB/s eta 0:00:03
#    ----------------------------------- --- 219.4/241.3 MB 10.8 MB/s eta 0:00:03
#    ----------------------------------- --- 221.8/241.3 MB 10.8 MB/s eta 0:00:02
#    ------------------------------------ -- 224.4/241.3 MB 10.8 MB/s eta 0:00:02
#    ------------------------------------ -- 227.3/241.3 MB 10.8 MB/s eta 0:00:02
#    ------------------------------------- - 229.9/241.3 MB 10.8 MB/s eta 0:00:02
#    ------------------------------------- - 232.8/241.3 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  235.1/241.3 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  237.8/241.3 MB 10.9 MB/s eta 0:00:01
#    --------------------------------------  240.6/241.3 MB 10.9 MB/s eta 0:00:01
#    --------------------------------------  241.2/241.3 MB 10.9 MB/s eta 0:00:01
#    --------------------------------------  241.2/241.3 MB 10.9 MB/s eta 0:00:01
#    --------------------------------------  241.2/241.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 241.3/241.3 MB 10.6 MB/s  0:00:22
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Installing collected packages: mpmath, sympy, networkx, jinja2, fsspec, filelock, torch
#
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------------- ---------------------- 3/7 [jinja2]
#    ----------------- ---------------------- 3/7 [jinja2]
#    ----------------- ---------------------- 3/7 [jinja2]
#    ----------------- ---------------------- 3/7 [jinja2]
#    ----------------- ---------------------- 3/7 [jinja2]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------- ----------------- 4/7 [fsspec]
#    ---------------------------- ----------- 5/7 [filelock]
#    ---------------------------- ----------- 5/7 [filelock]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------- ----- 6/7 [torch]
#    ---------------------------------------- 7/7 [torch]
#
# Successfully installed filelock-3.19.1 fsspec-2025.7.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 sympy-1.14.0 torch-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\keert\deeplearninglab\venv\lib\site-packages (2.8.0)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.8.0-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: setuptools in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torchvision) (2.3.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\keert\deeplearninglab\venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torchvision-0.23.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.1 MB/s  0:00:00
# Downloading torchaudio-2.8.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --------------------------------- ------ 2.1/2.5 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 10.2 MB/s  0:00:00
# Installing collected packages: torchvision, torchaudio
#
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    ---------------------------------------- 2/2 [torchaudio]
#
# Successfully installed torchaudio-2.8.0 torchvision-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch 
import torch.nn as nn
from torchvision import datasets,transforms
from torch.utils.data import DataLoader

# %%
transform=transforms.Compose([

    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

# %%
train_data=datasets.CIFAR10(root='./data',train=True,transform=transform,download=True)
test_data=datasets.CIFAR10(root='./data',train=False,transform=transform,download=True)
# Out:
# 100.0%

# %%
train_loader = DataLoader(train_data,batch_size=64,shuffle=True)
test_loader = DataLoader(test_data,batch_size=64,shuffle=False)

# %%
class CNN_Cifar10(nn.Module):
    def __init__(self):
        super().__init__()

        # feature extractor

        self.cnn1=nn.Conv2d(in_channels=3,out_channels=6,kernel_size=5)
        self.pool1=nn.MaxPool1d(2,2)

        self.cnn2=nn.Conv2d(6,16,3)
        self.pool2=nn.MaxPool2d(2,2)

        # classifier
        nn.Flatten()
        self.fc1=nn.Linear(6*6*16,4096)
        self.fc2=nn.Linear(4096,2048)
        self.fc3=nn.Linear(2048,1024)
        self.fc4=nn.Linear(1024,512)
        self.fc5=nn.Linear(512,256)
        self.fc6=nn.Linear(256,10)

    def forward(self,x):
        x=self.cnn1(x)
        x=nn.ReLU(x)
        x=self.pool1(x)

        x=self.pool2(nn.ReLU(self.cnn2(x)))
        x=nn.Flatten(x)
        x=self.fc1(x)
        x=nn.ReLU(x)
        x=self.fc2(x)
        x=nn.ReLU(x)
        x=self.fc3(x)
        x=nn.ReLU(x)
        x=self.fc4(x)
        x=nn.ReLU(x)
        x=self.fc5(x)
        x=nn.ReLU(x)
        x=self.fc6(x)

        return x

# %%
model=CNN_Cifar10()

criterian=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.0001)

# %%
for epoch in range(10):
    for images,labels in enumerate(train_loader):
        outputs=model(images)
        loss=criterian(outputs,labels)
        loss.backward()
        optimizer.zero_grad()
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 for epoch in range(10):
#       2     for images,labels in enumerate(train_loader):
# ----> 3         outputs=model(images)
#       4         loss=criterian(outputs,labels)
#       5         loss.backward()
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[9], line 23, in CNN_Cifar10.forward(self, x)
#      22 def forward(self,x):
# ---> 23     x=self.cnn1(x)
#      24     x=nn.ReLU(x)
#      25     x=self.pool1(x)
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\keert\DeepLearningLab\venv\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# TypeError: conv2d() received an invalid combination of arguments - got (int, Parameter, Parameter, tuple, tuple, tuple, int), but expected one of:
#  * (Tensor input, Tensor weight, Tensor bias = None, tuple of ints stride = 1, tuple of ints padding = 0, tuple of ints dilation = 1, int groups = 1)
#       didn't match because some of the arguments have invalid types: (!int!, !Parameter!, !Parameter!, !tuple of (int, int)!, !tuple of (int, int)!, !tuple of (int, int)!, !int!)
#  * (Tensor input, Tensor weight, Tensor bias = None, tuple of ints stride = 1, str padding = "valid", tuple of ints dilation = 1, int groups = 1)
#       didn't match because some of the arguments have invalid types: (!int!, !Parameter!, !Parameter!, !tuple of (int, int)!, !tuple of (int, int)!, !tuple of (int, int)!, !int!)
